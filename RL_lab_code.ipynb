# %%
# Install packages
# !pip install gymnasium
# !pip install numpy
# !pip install matplotlib

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

print("Gymnasium Version:", gym.__version__)
# Out:
# Gymnasium Version: 1.3.0

# %%
# Create the environment
env = gym.make("CartPole-v1")

# Reset the environment
observation, info = env.reset()

print("Initial Observation:")
print(observation)

print("\nEnvironment Information:")
print(info)
# Out:
# Initial Observation:
# [-0.04961804  0.04022124  0.03638311 -0.02515276]
#
# Environment Information:
# {}

# %%
print("Observation Space:")
print(env.observation_space)

print("\nAction Space:")
print(env.action_space)

print("\nObservation Space Type:")
print(type(env.observation_space))

print("\nNumber of Possible Actions:")
print(env.action_space.n)
# Out:
# Observation Space:
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
#
# Action Space:
# Discrete(2)
#
# Observation Space Type:
# <class 'gymnasium.spaces.box.Box'>
#
# Number of Possible Actions:
# 2

# %%
observation, info = env.reset()

done = False
step = 0
total_reward = 0

while not done:

    action = env.action_space.sample()

    observation, reward, terminated, truncated, info = env.step(action)

    done = terminated or truncated

    step += 1
    total_reward += reward

    print(f"Step {step}")
    print(f"Action: {action}")
    print(f"Observation: {observation}")
    print(f"Reward: {reward}")
    print(f"Episode Finished: {done}")
    print("-"*40)

print("Episode Completed")
print("Total Steps:", step)
print("Total Reward:", total_reward)

env.close()
# Out:
# Step 1
# Action: 0
# Observation: [-0.04130154 -0.18776019  0.04063046  0.3221145 ]
# Reward: 1.0
# Episode Finished: False
# ----------------------------------------
# Step 2
# Action: 0
# Observation: [-0.04505675 -0.38343647  0.04707275  0.62732875]
# Reward: 1.0
# Episode Finished: False
# ----------------------------------------
# Step 3
# Action: 0
# Observation: [-0.05272548 -0.57918274  0.05961933  0.9344572 ]
# Reward: 1.0
# Episode Finished: False
# ----------------------------------------
# Step 4
# Action: 0
# Observation: [-0.06430913 -0.77505606  0.07830847  1.2452629 ]
# Reward: 1.0
# Episode Finished: False
# ----------------------------------------
# Step 5
# Action: 1
# Observation: [-0.07981025 -0.58102113  0.10321373  0.9781015 ]
# Reward: 1.0
# Episode Finished: False
# ----------------------------------------
# Step 6
# Action: 0
# Observation: [-0.09143067 -0.77736413  0.12277576  1.3013396 ]
# Reward: 1.0
# Episode Finished: False
# ----------------------------------------
# Step 7
# Action: 0
# Observation: [-0.10697795 -0.9738113   0.14880255  1.6297978 ]
# Reward: 1.0
# Episode Finished: False
# ----------------------------------------
# Step 8
# Action: 1
# Observation: [-0.12645419 -0.7807184   0.18139851  1.3869457 ]
# Reward: 1.0
# Episode Finished: False
# ----------------------------------------
# Step 9
# Action: 1
# Observation: [-0.14206855 -0.588261    0.20913742  1.1560355 ]
# Reward: 1.0
# Episode Finished: False
# ----------------------------------------
# Step 10
# Action: 0
# Observation: [-0.15383378 -0.78540313  0.23225813  1.5063444 ]
# Reward: 1.0
# Episode Finished: True
# ----------------------------------------
# Episode Completed
# Total Steps: 10
# Total Reward: 10.0
